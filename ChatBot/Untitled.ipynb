# %%
import json
import numpy

# %%
f = open("WAChat.txt", "r")

# %%
a = []
for i in f:
    if "-" in i:
        g = i.split(":")
        try:
            a.append(g[2])
        except:
            pass
    else:
        a.append(i)

# %%
a
# Out:
# [' السلامُ علیکم\n',
#  ' Awais apne fake responses liye hain?\n',
#  ' Nope sarey organic hen\n',
#  ' Mtlb class k or khud enter kiye ho.\n',
#  ' Mene 12 tk organic kiye hain\n',
#  ' Wohi me bhi soch rha tha jitne easily ho skte hen kr lete hen\n',
#  ' Baki khud enter krlen ge\n',
#  ' Yes\n',
#  'Or jo data hm enter kre ge...usme errors bhi nhi ae ge\n',
#  ' 😂\n',
#  ' Yeh to he\n',
#  ' Class se krwae ge...to cleaning me hi nikl Jane hain sare\n',
#  ' Yup kyun ke mene dekha he kuch ne bas sar se utara he kaam\n',
#  ' Yes\n',
#  ' Apne sheet me convert kiya he data abhi m\n',
#  ' Usme ek issue a rha he\n',
#  ' Har question 2 se 3 time repeat hua wa he\n',
#  ' Sorry sorry my bad mujhe confusion ho gai thi All good 🌟\n',
#  ' ✨\n',
#  ' <Media omitted>\n',
#  ' Ye aap verify kr lo ek baar\n',
#  '\n',
#  'If possible.\n',
#  ' Yes mere according to theek he  🌟🌟\n',
#  ' This guy is 🔥😂\n',
#  ' Okay\n',
#  ' 😂\n',
#  ' 🌟🌟\n',
#  ' MashaAllah eshop ?\n',
#  ' Yes\n',
#  ' MashaAllah MashaAllah 🌟\n',
#  ' ✨\n',
#  ' 😂\n',
#  ' 😂😂\n',
#  ' Maima ?\n',
#  ' Yes\n',
#  ' Vlookup implement ho gya he \n',
#  'But the problem is keh woh dependant he uske corresponding column pe\n',
#  ' To ham ab unko to delete ni krakte\n',
#  ' Krskte*\n',
#  ' Haan G...to ese hi send krna ha\n',
#  ' Ohhh phir sahi he me soch rha tha keh hide krden\n',
#  ' Or pivot table bhi use krna he ?\n',
#  ' No need\n',
#  ' No\n',
#  'Just explore it\n',
#  ' Okay yani all done\n',
#  ' Byw do you use GB whatsapp ?\n',
#  ' Btw*\n',
#  ' Yes\n',
#  ' No\n',
#  'Recipient off\n',
#  ' Kher iska mujhe idea ni 😂\n',
#  ' Ok me file phir send krdeta hoon\n',
#  ' Settings me option ha\n',
#  ' Okay \n',
#  'Shukriya\n',
#  ' To iska faida hota he kuch ?\n',
#  ' Messages seen kr k reply nhi krna prta\n',
#  'Sender ko show nhi hota\n',
#  '\n',
#  '\n',
#  'Same goes for WhatsApp status\n',
#  ' 😂😂\n',
#  ' Yani kaam ki cheez he\n',
#  ' Issue is...\n',
#  'Receiver ne seen kr liya ha...ye bhi nhi pta chlta\n',
#  '\n',
#  "But I'm okay with it\n",
#  ' Yup\n',
#  'Specially for introverts\n',
#  '\n',
#  'غائب\n',
#  ' Oh yes yeh bhi he\n',
#  ' You introvert ?\n',
#  ' <Media omitted>\n',
#  ' Yes\n',
#  ' Here it is ek recheck krlijiye ga\n',
#  ' Oh same here \n',
#  'Milke khushi hui 🌟\n',
#  'On a journey to be extrovert 🥺\n',
#  ' Perfect\n',
#  ' Sir ko send kese krni ha\n',
#  ' Iska to idea ni he mujhe\n',
#  ' Kal class me dekh lenge\n',
#  ' Sir jaisay kahen ge wasay send krden ge\n',
#  ' Bht mushkil kaam ha\n',
#  ' Assignment',
#  'Explore pivot tables in excel.\n',
#  'Send me a consolidated excel sheet for whole group before next class. (Leaders to compile the sheet). Minimum responses for a group should be more than 82.\n',
#  ' Presentations ho rhin hen na\n',
#  ' Lekin yes waqai mushkil kaam he\n',
#  ' Ohhh me ab sahi tarhan parha\n',
#  ' Phir sir ko direct mag hi krna pare ga kren ap leader hen\n',
#  ' Haan ho hi rhi hain\n',
#  ' Okay ',
#  ' To it helps na\n',
#  ' Yes\n',
#  ' Sent*\n',
#  ' Mubarak Ho 🥳\n',
#  ' Hahah\n',
#  ' 😂\n',
#  ' 😂😂\n',
#  ' السلامُ علیکم\n',
#  ' Awais\n',
#  'Ap statements check kr lena\n',
#  ' Coding...me unse krwa lugi\n',
#  ' Wa alaikum asalam\n',
#  ' Actually filhaal to im outside subha inshaAllah check ho jayen gi\n',
#  ' Wasay bhi no issue next class tak ka time he\n',
#  ' Right ?\n',
#  ' Okay okay\n',
#  ' Yes\n',
#  ' 🌟🌟\n',
#  ' CB 2\n',
#  'PE 4\n',
#  'PE 5\n',
#  'TD 3\n',
#  'TD 5\n',
#  'OC 2\n',
#  'OC 4\n',
#  ' Maima mujhe to yeh mile hen\n',
#  'But inme bhi mujhe PE 4,5 me confusion he keh woh waqai hen keh nhi\n',
#  ' OC 2\n',
#  'Nhi ha...ye sir ne class me btaya tha\n',
#  ' Gmail\n',
#  'Why?!!\n',
#  ' Pata nhi kab ke msgs pare hue hen\n',
#  ' To prre rhne do😂\n',
#  ' Woh to he\n',
#  ' Lekin ab kuch zroori bhi emails ani hoti hen\n',
#  ' Yes im flexing 😂\n',
#  ' Btw\n',
#  'I forgot to tell you...k me graphic designing kr rhi hu\n',
#  ' Omggg😂\n',
#  ' Wasay bhi abhi to bas soch rha hoon clean krne ka dekho kab hoti he cleaning start\n',
#  ' MashaAllah\n',
#  ' 😂😂😂\n',
#  ' Freelancing ?\n',
#  ' Irade bandhta hu sochta hu\n',
#  '\n',
#  '\n',
#  'A kind of😂\n',
#  ' 😂😂😂😂😂\n',
#  ' No\n',
#  'Abhi beginning softwares pe hu\n',
#  ' Ohh phir to nice he\n',
#  'Apki field se related bhi he\n',
#  ' Ai or Ps ...\n',
#  '2 3 or krlu ... then\n',
#  ' Finance se?\n',
#  ' How😂\n',
#  ' Ni pehle na ek ko excel krlen\n',
#  ' 😂 ni matlab Mirza Arts se\n',
#  ' Acha\n',
#  ' Aww acha😂\n',
#  ' He keh nhi kher\n',
#  ' Maima btw i had a question\n',
#  ' G\n',
#  ' Poochun ga ghar ja ke\n',
#  ' Apke name se related he\n',
#  ' Sure\n',
#  ' Oka then 🌟\n',
#  ' Hello g\n',
#  ' <Media omitted>\n',
#  ' Haan g😂\n',
#  ' Acha first of all\n',
#  ' Apne mind ni krna ok ?\n',
#  ' Kyun i know question mind krne wala he\n',
#  ' Theek ?\n',
#  ' Okay👀\n',
#  ' 😂\n',
#  ' Acha you have Ismail and Also Mirza in your name\n',
#  ' Yes\n',
#  ' Which is kind of suspecious to me\n',
#  ' Mujhe tbh in cheeOn ka zyada knowledge nhi he\n',
#  ' Cheezon*\n',
#  ' Ismail is my father name\n',
#  ' Not ismaili\n',
#  ' Yani you are Muslim ?\n',
#  ' 😂😂\n',
#  ' Haan g\U0001f972\n',
#  ' Mirza is...mughal\n',
#  ' Mughals are also called mirza\n',
#  ' And you Believe Hazrat Muhammad is the last prophet ?\n',
#  ' Ohhh i see woh walay Mirza\n',
#  ' To mje mirza cool lgta h...mene vo lga liya\n',
#  ' Haan g\n',
#  ' Yes\n',
#  'Mirza ghalib\n',
#  ' Yes yes Woh to he phir\n',
#  ' 😂😂😂\n',
#  ' Acha mind to ni kiya na m\n',
#  ' ?*\n',
#  ' And mirzai \n',
#  'Vo is liye ye kehlate hain...vo jisko follow krte the...vo mirza tha\n',
#  '\n',
#  'Lkn mirza dusre bhi exist krte hain\n',
#  ' Wohi na mene bataya mujhe wasay itna knowledge ni he 🥺lekin \n',
#  'Cheezen clear achi lagti hen\n',
#  ' Nhi nhi\n',
#  'Meri sister ne mje 1 baar kaha tha k naam change krlo\n',
#  'Jamiyat wale aa jae ge😂\n',
#  ' Haan achi baat h\n',
#  'You asked.\n',
#  ' Class me or bhi pta ni kitno ko lgta hoga\n',
#  ' Han na wasay apke Documented name bhi Simple sa he\n',
#  'Mujhe bhi Simple krwana he :)\n',
#  ' <Media omitted>\n',
#  ' Ni wasay mujhe zyada shaq is baat pe hua tha \n',
#  'Ap MashaAllah full niqab ya hijab bhi krti hen \n',
#  'To woh Mirzai ka bhi suna he keh woh bhi aisay hi krte hen\n',
#  ' Disclaimer me discourage nhi kr rha ⚠️\n',
#  ' Balkey yeh to boht achi baat he \n',
#  'I appreciate🔥🌟\n',
#  ' 🤣🤣🤣\n',
#  'I can understand 😂\n',
#  ' ',
#  'Ab to adat si he :)\n',
#  ' Ni ni\n',
#  'Vo to mene 2nd semester me start kiya tha\n',
#  'Apne introversion k chkro me😂\n',
#  ' Shukriya✨\n',
#  ' Ap pehle ni krti thin ?\n',
#  ' Wahhh\n',
#  ' No\n',
#  ' Acha mujhe ni yaad\n',
#  ' I dont remember mene apka kabhi chehra dekha ho\n',
#  ' Full Assassin\n',
#  ' Acha sorry\n',
#  " Bcz I'm introvert \n",
#  "Shuru me koi friend nhi the...May be that's why me class le k bhag jati thi\n",
#  " It's ok\n",
#  ' Ni ni sahi he\n',
#  ' Aisay hi rehna he \n',
#  'Allah apko mazeed himmat de 🌟\n',
#  ' ✨\n',
#  ' Acha kal exonomics ka koi kaam to ni he ?\n',
#  ' Economics*\n',
#  ' Sb institutions k heads k names and details check krne hain\n',
#  ' Btw ek or thing nice dp 😂\n',
#  ' 1 passage likhna ha\n',
#  ' <Media omitted>\n',
#  ' Oh hann right right\n',
#  ' Thanks 🌟🌟\n',
#  ' No need l✨\n',
#  ' No need*\n',
#  ' 🌟🌟\n',
#  ' Maima ?\n',
#  ' G\n',
#  ' Apne Stats ki assignment start ki he ?\n',
#  ' Pivot tables nhi kiye\n',
#  ' Vlookup implement ho gya ?\n',
#  ' Yes\n',
#  ' Heavy🔥\n',
#  ' ',
#  ' Send krden mere se ni ho rha mene to Sir ko bhi msg krdiya he is chakkar me 🥺\n',
#  ' Shabash\n',
#  ' Send krti hu\n',
#  ' Yeh taunt tha ya motivation ?\n',
#  ' Allah apka bhala kre 🔥\n',
#  ' <Media omitted>\n',
#  ' Obviously taunt👀\n',
#  ' Yar ? Banda help bhi ni maang skta ? 🥺\n',
#  ' Yeh kya baat hui boss mene bhi same formula input kiya he mujhe N/A show kr rha tha \n',
#  'Kher ab me check krta hoon \n',
#  'Thanks Maima 🌟\n',
#  ' <Media omitted>\n',
#  ' Mang lo bhii\n',
#  ' Selections same hain?\n',
#  ' No problem\n',
#  ' Ditto copy\n',
#  ' Btw yeh apke liye thi keh ap introvert hen and you still scoring the most ',
#  'Rational Investor banen 😂\n',
#  ' Monday ki tension bhi ho rhi ha\U0001f972\n',
#  ' Same here 🤧\n',
#  ' Introversion causing high scores\n',
#  ' Mujhe is logic ke peeche ki science chahiye\n',
#  ' Koi Boht cool stuff lag rha he\n',
#  ' Agr kbhi esa ho gya to pta ni mera kiya hoga\n',
#  'Mera to presentation k wqt BP low ho jata h\U0001f972\n',
#  '\n',
#  'I need cloak of invisibility\n',
#  ' Whyyyy everyyyyyoneeee wannaaaaaa beeee invisibleee\n',
#  ' Ap Ese hi bolte ho\n',
#  'Acha bhla bol lete ho class me\n',
#  ' Presentations me bhi\n',
#  ' Told you im on a journey to be extrovert \n',
#  'So i have come a long way \n',
#  'To isliye kuch progress ho gai he wrna first 2 semesters mera to koi friend bhi ni tha\n',
#  ' I think we were same at that point\n',
#  'Phir mene Extrovert banne ka socha \n',
#  'Or apne mazeed introvert :)\n',
#  ' Time waste hone ki opportunities ni milti naa\n',
#  '\n',
#  '\n',
#  'Vese on a very serious note...me tb prhti hu jb koi assignment quiz ya paper aa jae...\n',
#  '\n',
#  'Badnaam kiya hua ha\U0001f972\n',
#  ' Badnaami wali kya baat he \n',
#  'Apko proud hona chahiye \n',
#  'You know what I call you ?\n',
#  'The Giants 😂\n',
#  ' Ho hi jana chahiye\n',
#  ' Wasay yess apki time waste wali baat bilkul theek he \n',
#  'Lekin mujhe lagta he Communication Skills zyada matter krti hen\n',
#  ' <Media omitted>\n',
#  ' Or is sticker ki mujhe samajh ni ati\n',
#  ' <Media omitted>\n',
#  ' 😂😂😂😂🔥\n',
#  ' Haan krti hain... I know \n',
#  'Nhi dil krta mera bolne ka\n',
#  '\n',
#  '\n',
#  'Kiya kru me mar jau!?😂😂\n',
#  ' مطمئن \n',
#  'Ye meaning h...\n',
#  ' To it means apko being extrovert me koi interest hi ni he\n',
#  ' Phir ab kya keh skte hen\n',
#  ' Mutmain to woh kahin se ni lagta 😂\n',
#  ' Kh skte hain\n',
#  '\n',
#  'Bcz deep inside...mje vo log bht annoying lgte hain...jo bohat bolte ha...\n',
#  '\n',
#  'Me chah k bhi vo bn ni skti\n',
#  ' Yess yeh to he\n',
#  'Yeh to me bhi kehta hoon\n',
#  ' <Media omitted>\n',
#  ' Ohhhhhh tabhiiii\n',
#  ' Tabhi ap chat bhi itna soch soch ke krti hen\n',
#  ' Ever played chess ?\n',
#  ' \U0001f972\n',
#  ' No\n',
#  ' My father is very good player.\n',
#  '\n',
#  'But unho ne kbhi sikhai hi nhi\U0001f972\n',
#  ' Ni bhai me ni bolta itna \n',
#  'Me bas unke sath bolta hoon jinke sath comfortable hoon\n',
#  ' Seekhna \n',
#  'Jitna ap soch soch ke kaam krti hen na\n',
#  'InshaAllah boht agay jayen gi\n',
#  ' 🤝🏻\n',
#  ' Maths krwa rhi hu\n',
#  ' Aha sorry I take my words back 😂\n',
#  ' Ap bata detin you are busy\n',
#  ' Oka keep up the work 🌟\n',
#  ' ✨\n',
#  ' Meri Abhi Sir Se Baat Hui Thi To Sir Keh Rhe Thay Ap Group Lead Se Baat Krke Apne Group Me Msg Krden Keh\n',
#  'Agar Kisi Ko Help Chahiye Ho To Hamse Pooch Len Takey Unki Bhi Help Ho Ske\n',
#  ' Or Mera Pivot Table Bhi Ho Gya He\n',
#  ' Oh Sir Ne Group Me Bhi Yeh Kehdiya He \n',
#  'Ok Nvm 😂\n',
#  ' Bro\n',
#  'Location vise me karachi 2 baar aa rha h...mera\n',
#  '\n',
#  'Apka a rha?\n',
#  ' 😂\n',
#  ' Mene yeh note nhi kiya \n',
#  'And sorry for being late\n',
#  ' Yes Aisa Hi He Mene\n',
#  'Woh Actually Me Kuch Beech me Karachi He Jo\n',
#  '"Karachi" hen or kuch\n',
#  '"Karachi " hen\n',
#  'I mean kuch ke agay ek space extra he \n',
#  'Uski wajah se Pivot table unko alag show kr rha he\n',
#  ' 38 to 43 cell walay karachi me zyada space he usko check krlijiye ga\n',
#  ' No issue\n',
#  ' Okay okay\n',
#  'Shukriya✨\n',
#  ' No Need 🌟\n',
#  ' 🌟🌟💖\n',
#  ' ✨\n',
#  ' <Media omitted>\n',
#  ' Rename it\n',
#  ' F20BA025 Muhammad Awais Mutahir Qadri Stats Assignment 2.xlsx\n',
#  ' 🤣\n',
#  ' ',
#  ' Me ni khel rha\n',
#  ' Jao na kro\n',
#  'Sir ne kaha tha\n',
#  ' F20BA025 Awais Mutahir\n',
#  ' Thats it\n',
#  ' =)\n',
#  ' <Media omitted>\n',
#  ' Sbki receive ho jae...then mail kru gi\n',
#  ' Oka 🌟\n',
#  ' Maima ?\n',
#  ' Yes?\n',
#  ' Insta pe id show hui he apki req send krdoon?\n',
#  'Agar no bhi bolen to No problem\n',
#  ' Kr dain\n',
#  'No problem\n',
#  ' Oka 🌟\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' 🔥🙌🌟\n',
#  ' ✨\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' Naiiiiii 😂\n',
#  ' <Media omitted>\n',
#  ' Matlab half building dark half in day\n',
#  ' \U0001f972\n',
#  ' Kher koi baat ni\n',
#  'Thanks\n',
#  'Apne itni effort ki he 🔥🌟\n',
#  ' And I was thinking...\n',
#  'Kiya bcho wali batein kr rha ha\n',
#  ' Koi baat ni\n',
#  'Koi meri baton ko serious ni leta \n',
#  'All good 😂\n',
#  ' Chlo ye ab raat tk hi hoga\n',
#  ' 🤣\n',
#  ' 😂🌟\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' Disclaimer',
#  ' Ouffff Heavyy 🔥\n',
#  ' Peeche wale trees adjust ho gye hain...agay wale ni ho rhe🤷🏻\u200d♀️\n',
#  ' Ni ni unka masla bhi ni itna\n',
#  ' Thanks Maima 🌟\n',
#  ' 🤏🏻🕶️\n',
#  ' 😂😂\n',
#  ' No need\n',
#  ' 🌟🌟\n',
#  ' Kitne time me edit hui he ?\n',
#  ' 20 approximately\n',
#  ' Because I was trying to adjust trees\U0001f972\n',
#  ' Ohh phir to sahi he\n',
#  ' Pro log\n',
#  ' <Media omitted>\n',
#  ' 😂😂 ok Maima\n',
#  ' 😂\n',
#  ' <Media omitted>\n',
#  ' Bro🤩\n',
#  "It's looking more realistic\n",
#  ' Tools?\n',
#  ' Waqai ?\n',
#  ' Photoshop ka online replica\n',
#  'Photopea\n',
#  ' Haan\n',
#  ' Mene bas gradient use kiya\n',
#  ' Content aware\n',
#  ' Acha acha\n',
#  ' Hlka sa center me blurr ha\n',
#  ' Chalo phir yeh story pe lagate hen 😂\n',
#  ' Jo k gradient ki vja se hi hua h shyd\n',
#  ' Yess wohi to point tha na \n',
#  'To thori pic hilne ki wajah se a gya\n',
#  ' Haan lga lo\n',
#  ' Ap bura to ni manayen gi ',
#  ' Meri wali me ni aya🤏🏻🕶️\n',
#  ' 😂😂😂\n',
#  ' Apki story ha\n',
#  'Me bura q manu gi🤷🏻\u200d♀️\n',
#  ' Ni tbh apki wali achi he\n',
#  ' Dil rakhne k liye ni keh rha\n',
#  ' Allah apka bhala kre\n',
#  ' <Media omitted>\n',
#  ' Or ek yeh sticker\n',
#  ' Allah maaf kre\n',
#  ' <Media omitted>\n',
#  ' ',
#  'Marzi he janab\n',
#  " Mirza's Marzi\n",
#  ' Mirza remove kr diya ab\U0001f972\n',
#  ' Is se phle k someone shoot me\n',
#  ' Apka to scene hi easy he\n',
#  'Jab dil kiya add krlo jab dil kiya remove krlo\n',
#  ' 🤣🤣🤣\n',
#  ' Oh ni ni \n',
#  'Mene oron se bhi poocha tha everyone was like han to is name me aisa kya he\n',
#  ' BTW\n',
#  'Fazli family name ha?\n',
#  ' Yeh bhi Qadri ki tarhan hi he\n',
#  ' Mje 1 or ne bhi kaha tha😬\n',
#  ' Phir change krna banta he\n',
#  ' Oho\n',
#  'Ye bhi official name me likhwa dete\n',
#  ' I think aj k liye kafi izzat ho gai he meri\n',
#  ' <Media omitted>\n',
#  ' Iska badla dena pare ga\n',
#  ' This is from your side\n',
#  ' Ab ek chota sa kaam kren\n',
#  ' From my side hota to me send kr deta ',
#  ' Plz 🥺\n',
#  ' 👀\n',
#  ' 😂😂\n',
#  ' Mene story lagani he\n',
#  ' Uske liye ek ya 2 words ki line batayen\n',
#  ' As a caption\n',
#  ' Doesnt matter if it make sense or not\n',
#  ' Me ne "not different" socha tha\n',
#  ' Mje ese kaam ni ate😬\n',
#  ' Good ha\n',
#  ' Or mene to suna tha \n',
#  'Artist bare creative hote hen\n',
#  ' 🌟\n',
#  " I'm not an artist🤏🏻🕶️\n",
#  ' Mirza Artist\n',
#  ' Designer*\n',
#  ' Vo me nhi hu\n',
#  'Sister hain\n',
#  ' designer artist me hi ni a jata ',
#  ' Sister ka thora sa influence to hoga ',
#  ' Mjse seedhi line draw ni hoti\U0001f972\n',
#  ' Kher\n',
#  ' Woh mujhse bhi ni hoti 😂\n',
#  ' Not different\n',
#  ' 🙌😂\n',
#  ' ',
#  ' Krdi upload\n',
#  ' Do you have that sticker ?\n',
#  ' Tu ha ... tere ko pta ni...\n',
#  ' <Media omitted>\n',
#  ' Sticker ni he\n',
#  ' <Media omitted>\n',
#  ' Isko bhala kya kehte hen\n',
#  ' Apne paoon pe kulhari marna\n',
#  ' Exactly\n',
#  ' Mujhse hi meme mangwa kr mujhe hi\n',
#  ' Ok Maima\n',
#  ' You doing great\n',
#  ' <Media omitted>\n',
#  ' 😂😂😂\n',
#  ' Acha chalen g\n',
#  ' Oka\n',
#  ' Allah Hafiz 🌟\n',
#  ' Allah hafiz\n',
#  ' Maima\n',
#  'Yeh Assignment Me Kya Krna He\n',
#  'Bas Data Paste Krke Variables Declare Krdene Hen ?\n',
#  ' Or ohir apko files send krni hen ?\n',
#  ' Yes\n',
#  ' 🌟🌟\n',
#  ' Spss me import krlo\n',
#  '\n',
#  'Phir ap edit kr lena\n',
#  ' Ese variables sare nhi likhne prein ge\n',
#  ' <Media omitted>\n',
#  ' Thanks for suggestion 🌟🌟\n',
#  ' Friday bhi on\n',
#  ' Yeah\n',
#  ' Mazayy\n',
#  ' ✨\n',
#  ' Good ho gya\n',
#  ' 🌟🌟\n',
#  ' <Media omitted>\n',
#  ' Variable name is form me likhne hain',
#  'RS1\n',
#  'RS2\n',
#  '\n',
#  'because ye graphs me show hote hain...as it is\n',
#  ' Oh ok ok me krta\n',
#  ' <Media omitted>\n',
#  ' all good ?\n',
#  ' Laptop nhi ha\n',
#  ' Ghar ja ka check kru gi\n',
#  ' Ok ok no problem\n',
#  ' <Media omitted>\n',
#  ' Meanwhile \n',
#  'One who asked\n',
#  ' 😂😂🙌\n',
#  ' Open ended questions nominal nhi hoge?\n',
#  ' Such as ?\n',
#  ' Designation and organization\n',
#  ' Organization to nominal hi hogi\n',
#  ' Hmare forms me open ended hain na\n',
#  ' Or designation shayid mujhe laga ek hi scale pe hen is liye mene i think ordinal laga di hogi\n',
#  ' Sorry for that\n',
#  ' My bad\n',
#  ' Mje to khud sure ni h\n',
#  ' Pooch rhi hu me\n',
#  ' Ni ni dono nominal hi honge\n',
#  ' Okay okay\n',
#  ' Mene ordinal lagaye hue hen ?\n',
#  ' Designation ko\n',
#  ' Krdu change?\n',
#  ' Kr den Allah apka bhala kre 🥺\n',
#  ' Me to ab kyun ke monday se pehle ni kr skta\n',
#  ' <Media omitted>\n',
#  ' ✨\n',
#  ' Krdiye ?\n',
#  ' yes\n',
#  ' Thanks Maima 🙌🌟\n',
#  " You're welcome\n",
#  ' 🌟🌟\n',
#  ' This is brutal\n',
#  ' It is!!\n',
#  ' Ab aisay kheyal ane hen\n',
#  ' Me aisay late night ni jagta ',
#  ' Ok no personal attacks\n',
#  ' 💀\n',
#  ' Achi routine\n',
#  ' Alhamdulillah\n',
#  ' Thuwanu neend ni andi ? 😂\n',
#  ' Actually meri routine 18 sal se khrab ha\n',
#  ' Qk meri family ki routine khrab ha\n',
#  ' Ok Maima pata lag gya he ap 18 ki hi hen abhi tak\n',
#  ' Working days me...me achi routine krti hu\n',
#  'Weekend pe khrab kr dete hain\U0001f972\n',
#  ' Yeah family plays a big role lekin ... Kher ab kya keh skte hen\n',
#  ' Ni hu bro\n',
#  "I'm trying to follow achi routine \n",
#  'From almost 1 year\n',
#  ' Desperately longing for sunday \n',
#  'Boht sona he\n',
#  ' To vo mene minus kr diya ha😎\n',
#  ' Dekha bataye bager rha nhi gya\n',
#  ' Acha sorry 😂\n',
#  ' Afsos ',
#  ' Lol\n',
#  "I'm telling you that I'm older\n",
#  ' Still young\n',
#  ' Kher\n',
#  ' Choren in baton me kuch ni rakha 😂\n',
#  ' Take care\n',
#  ' Good night\n',
#  ' 🙏🏻\n',
#  ' Yeh high five he ya maafi ?\n',
#  ' Allah hafiz\n',
#  ' Pakistani hain\n',
#  'Mafi hi h\n',
#  ' Maafi for what ?\n',
#  ' Ye jo aap baat ki khaal utarte ho👀\n',
#  ' 😂😂😂🌟\n',
#  ' Aatleast kisi ne honest opinion to diya 🔥\n',
#  ' Ni utara krun ga ab se\n',
#  ' Thanks 🌟\n',
#  ' Good ho gya\n',
#  ' Allah Hafiz 🌟\n',
#  ' السلامُ علیکم\n',
#  ' Awais\n',
#  'Assignments class se phle mail krni hain?\n',
#  'Sir ne esa kuch kaha tha?\n',
#  ' I dont remember\n',
#  ' Lekin ap krden\n',
#  ' I was busy\n',
#  'To mene mail nhi ki\n',
#  ' Chalen phir \n',
#  'I dont think so koi masla hoga\n',
#  ' Haan nhi hua\n',
#  ' <Media omitted>\n',
#  ' Whats this\n',
#  ' Values enter krdi hain\n',
#  ' To ab se isi file pe ap further tasks kr lena\n',
#  ' Thanks Maina 🙌\n',
#  ' Maima*\n',
#  ' No problem\n',
#  ' Congratulations🙌✨\n',
#  ' Abhi more rounds to go\n',
#  ' More rounds to win✨\n',
#  ' انشاءاللہ\n',
#  ' InshaAllah InshaAllah\n',
#  ' Maima ?\n',
#  ' Yes\n',
#  ' Can you please tell stats or IT ki assignment kya kya hen ?\n',
#  ' IT ki assignment 1?\n',
#  ' Woh MS Access\n',
#  ' Stats ki \n',
#  'Abhi sir ne complete instructions deni hain\n',
#  ' Or vo group leader ne krni h\n',
#  ' Simple si ha\n',
#  '4 Tables create krne hain...\n',
#  "Jese class me krwae the ma'am ne\n",
#  ' Or 25 rows enter krni hain\n',
#  ' <Media omitted>\n',
#  ' Rows apne paas se ?\n',
#  ' Yes\n',
#  ' Ohhh chalen Thank you soo much\n',
#  ' Assignment 2 ki deadline kiya h?\n',
#  ' No problem\n',
#  ' Sunday\n',
#  ' Ek min kiski assignment 2 ?\n',
#  ' Acha\n',
#  ' IT\n',
#  ' Ap hi ne to bataya he 😂\n',
#  ' .\n',
#  ' Ye assignment 1 ha\n',
#  ' Assignment 2 bhi he ?\n',
#  ' 🥴\n',
#  " Slides me dikhai thi ma'am ne\n",
#  ' Mujhe laga woh yehi he\n',
#  ' Kher woh wali slides maam ne upload kin hen ?\n',
#  ' <Media omitted>\n',
#  ' Ok Maima Ok\n',
#  ' <Media omitted>\n',
#  ' Haan\n',
#  ' Ni iska idea ni he mujhe\n',
#  ' Chalen kher\n',
#  ' Marketing ki bhi ha😶\n',
#  ' Na chero hame ham sataye hue hen\n',
#  ' (',
#  ' Ek to mujhe iski samajh ni ati\n',
#  ' Kher\n',
#  ' No baal ki khaal\n',
#  ' So enjoy\n',
#  ' Baat*\n',
#  ' Its baal ki khaal\n',
#  ' You may search\n',
#  ' Waqae\n',
#  ' Yup\n',
#  ' Ohh yes\n',
#  ' Shukriya bro\n',
#  ' ',
#  ' Anytime bro\n',
#  ' GR is going to send weekend diary🤣\n',
#  ' Allah uska bhala kre 🙌\n',
#  ' ✨\n',
#  ' Carry on\n',
#  ' Me to bas aivin\n',
#  ' Vibes\n',
#  ' Good ha😂\n',
#  ' 🌟🌟\n',
#  ' Matlab',
#  ' Purpose of brain, eyes, tongue\n',
#  ' Jo creator ne btaya ha...purpose to vohi hua na\n',
#  ' Ohhh spirituality\n',
#  ' Designed bhi usi k liye hue hoge\n',
#  ' 🙌🙌🥺\n',
#  ' Yes\n',
#  ' Allah ham sabko hidayat de 🌟\n',
#  ' Ameen✨\n',
#  ' Bro\n',
#  ' 1 kaam krdo\n',
#  ' Allah kher kre\n',
#  ' Meri na oral or written communication skills \n',
#  '\n',
#  'Dono hi shadeed khrab halaat me h\n',
#  ' Us din\n',
#  'Library me\n',
#  '\n',
#  'Content writing ki baat ki thi ap ne\n',
#  ' Kuch ho skta ha to bta do\n',
#  ' I am ready to do.\n',
#  ' Content writing k liye ya communications skills develop krne k liye ?\n',
#  ' Content writing se written communication skills bhtr hoti ha\n',
#  ' Google khta ha\n',
#  ' Sahi kehta he\n',
#  ' Then\n',
#  ' Then ?\n',
#  ' Bhai ek hi baat he\n',
#  ' Agar apne communication skills develop krni hen\n',
#  ' To simple thing is\n',
#  ' Communicate kiya kre\n',
#  ' Kren*\n',
#  ' Class me handsfree laga kr apne ap me bethay rho ge to kya hoga\n',
#  ' OK awais ok\n',
#  ' Us din library me pooch rhe the\n',
#  ' Content writing krni h\n',
#  ' Aya yaad?\n',
#  ' Jo mene mna kr diya tha\n',
#  ' Mene poocha tha content writing krti hen ?\n',
#  ' Agar nhi to kiya kren\n',
#  ' Class me kafi log krte hen (apne paas se bola tha)\n',
#  ' Mje galat smjh ai thi phir ',
#  ' ',
#  ' Chlo\n',
#  ' Krte h kuch\n',
#  ' To ao content writing krna chah rhin hen ?\n',
#  ' Haan\n',
#  ' Nice nice\n',
#  ' Kher mujhe to iska kuch khas idea ni he\n',
#  ' I think Uswa krti thi you may ask her\n',
#  ' Haan\n',
#  ' Vo krti thi...\n',
#  'Isi liye apse poocha ha\n',
#  ' Anyways\n',
#  'Shukriya🙌\n',
#  ' Na me krta tha \n',
#  'Na me krta hoon :)\n',
#  ' Anyways \n',
#  'Welcome 🌟\n',
#  ' Cheez hi bqwas ha\n',
#  ' Yeh kya baat hui ?\n',
#  ' Galat ni kh rhi\n',
#  ' Kyun ?\n',
#  ' Usme aisa kya he ?\n',
#  ' Uswa bhi yehi khti h\n',
#  ' Sochna prta h\n',
#  ' Yeh to logic nhi he\n',
#  ' If something is not of your type doesnt mean its bakwaas\n',
#  ' Over praising \n',
#  'Over writing krni prti h\n',
#  ' Ye better h',
#  ' It depends on nature of content you write\n',
#  ' Haan shyd\n',
#  ' Kher mujhe woh oaisay ni dete apni field ko deoend krne ke\n',
#  ' So ho sita he waqai fazool ho\n',
#  ' No comments\n',
#  ' Chchch🤣🤣\n',
#  ' 🌟🌟\n',
#  ' ',
#  ' 😂😂\n',
#  ' This\U0001f972\n',
#  ' Yes it hurts ',
#  ' ',
#  ' Kya hua he ?\n',
#  ' It hurts ka response diya h',
#  ' Ohh\n',
#  ' I\n',
#  ' See\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' Mene apki information me izafa kiya ha ',
#  ' Maima after this\n',
#  ' https',
#  ' Me hun\n',
#  ' Changa? ',
#  ' Changi ',
#  ' MashaAllah\n',
#  ' 🤏🏻🕶️\n',
#  ' <Media omitted>\n',
#  ' Thanks for sharing\n',
#  ' No problem😂\n',
#  ' 🌟🌟\n',
#  ' السلامُ علیکم\n',
#  ' Apne finance ka q 7 kiya ha?\n',
#  ' Wa alaikum asalam\n',
#  ' Abhi to finance nhi kiya\n',
#  ' InshaAllah parson ',
#  ' Okay okay\n',
#  ' 🌟🌟\n',
#  ' Maima mene Q7 try kiya he solve krne k liye\n',
#  'Agar apko uske formula me problem a rhi he to \n',
#  'Formula Present Value Of Ordinary Annuity Ka Use Hoga\n',
#  '\n',
#  'Or agar uske complexity me problem a rhi he keh interest ki value kese find out krni he to uske liye neeche wali video may help\n',
#  ' https',
#  ' Agar apko koi or tareeqa mila ho to mujhe bhi zroor batana \n',
#  'And sorry for being late 🌟\n',
#  ' Formula arrange ni ho rha tha\n',
#  ' Okay okay\n',
#  ' Mje nhi mila\n',
#  ' Thank you so much✨\n',
#  ' 🌟🌟\n',
#  ' No issue 🌟\n',
#  ' ✨\n',
#  ' #introverts\n',
#  ' <Media omitted>\n',
#  ' 😂😂😂🙌\n',
#  ' 😂\U0001f972\n',
#  ' These are looking like barbie bags\n',
#  ' Still\n',
#  'Can be fit in\n',
#  ' Mat sadness phelayen kal uni bhi jana he shukriya\n',
#  ' <Media omitted>\n',
#  ' 😂\n',
#  ' \U0001f972😂\n',
#  ' 😂😂\n',
#  ' Assalam o alaikum \n',
#  '\n',
#  'I was creating canva account on my university Gmail. \n',
#  '\n',
#  'And I added yours.\n',
#  '\n',
#  "That's why, canva sent you the code.\n",
#  '\n',
#  'It was unintentionally. Ignore it.\n',
#  ' Ok ok no issue 🌟\n',
#  ' Yeh kab hua\n',
#  ' Update hone wala tha mera...\n',
#  ' 😂 oh sad\n',
#  ' \U0001f972😂\n',
#  ' Actually light has gone\n',
#  ' 🤣🤣🤣🤣🤣🤣🤣🤣🤣\n',
#  ' To me yahan baat continue kr deta hoon 😂\n',
#  ' Sure😂😂😂\n',
#  ' Mujhe bhi notification a gya tha keh\n',
#  'Maima Ismail has visited your profile\n',
#  ' Linkedin pe to banda wasay hi thora exagerate kr deta he cheezon ko ',
#  ' Request bhi send ki thi\n',
#  ' Accept bhi krli thi\n',
#  ' Mene to terms phli baar prhi thi🙃\n',
#  ' Yey mera personal opinion he generalize ap khud apne risk pe kren\n',
#  ' Acha\n',
#  ' Apne finance rakhni he na 🤧\n',
#  ' Vo sari IT ki nhi thi bro\U0001f972\n',
#  ' Or konsi thi ?\n',
#  ' Haan...mene bhi top skills me photoshop likha hua h🤡\n',
#  ' Woh to apko ata bhi he\n',
#  ' Data analysis\n',
#  ' Han woh ham IT ki field me reh kr hi krte hen\n',
#  ' Ata h...or top skills me there is a huge difference\n',
#  ' Ohh 😂\n',
#  ' Acha...\n',
#  ' Yup\n',
#  ' Chalen kher\n',
#  ' Awais...\n',
#  ' Oka Take care good night\n',
#  ' G ?\n',
#  ' Apka finance or economics ka group bn gya h?\n',
#  '\n',
#  '\n',
#  'Mtlb...agr nhi to...hmara bhi nhi bna\n',
#  '\n',
#  '\n',
#  'But...agr NO to no issue...\n',
#  ' Baat complete krlu\U0001f972\n',
#  ' Ni mera to ni bana\n',
#  ' Or abhi to kisi ne bhi ni banaye\n',
#  ' Acha\n',
#  ' Masooma maha\n',
#  ' Vo bna rhe the\n',
#  ' To mje lga sb bna rhe h\n',
#  ' Acha phir shayid kahin me na soya reh gya hoon class me\n',
#  ' Kher\n',
#  ' Apke group me kon kon he ?\n',
#  ' 😂\n',
#  ' Me uswa\n',
#  ' As always\n',
#  ' MashaAllah\n',
#  ' Agr no tb bhi msla nhi\n',
#  ' Theek he 2 giants ke saath kaam krke acha lage ga\n',
#  " It's totally okay\n",
#  ' Maima mujhe khushi hogi apke group me akay\n',
#  ' Kbhi assassin khte ho...kbhi giant \U0001f972\n',
#  ' Okay boss🤝\n',
#  ' Giants in term or parhai\n',
#  ' Okay\U0001f972😂\n',
#  ' Of*\n',
#  ' 3 se zyada hi members hoge\n',
#  ' G g no issue\n',
#  ' To agr apne kisi ko add krna hua to ap kr lena...\n',
#  'Vrna search kr lege\n',
#  ' Ni yeh kaam ap log hi kren\n',
#  ' Sure😂\n',
#  ' Chlo...ab good night\n',
#  ' Yup 🙌\n',
#  ' Assalam o alaikum\n',
#  ' Apne note kiya tha...k stats ka kiya kiya krna h?\n',
#  ' Assingment me\n',
#  ' Nope mene dekha keh ap log note kr rhe hen to mene kiya ni ',
#  ' I was absent',
#  ' Sir kh rhe hain...kr dete h send\n',
#  ' Noo you were writing something\n',
#  ' Kher ho bhi skta he\n',
#  ' Shukrr\n',
#  ' Yoooo\n',
#  ' Wasay sir ne to abhi kuch upload ni kiya he na ?\n',
#  ' Haan\n',
#  ' Is it yes or no ?😂\n',
#  ' Mtlb...nhi kiya upload\n',
#  ' I will share data and requirements today\n',
#  ' Ok ok 🙌\n',
#  ' ~Sir\n',
#  ' Chalo yani kal ispe discussion bhi ho jaye gi\n',
#  ' InshaAllah\n',
#  ' Yup\n',
#  ' Dekh li guidelines \U0001f972\n',
#  ' Abhi dekhta hoon\n',
#  ' Acha\n',
#  ' Yeh to boht lambi he\n',
#  ' Assignment ya file😂\n',
#  ' Donoo\n',
#  ' InshaAllah krte hen friday se working start\n',
#  ' Atleast from my side\n',
#  ' Haan ye theek h\n',
#  ' Kl tk baqi kaam kr lete hain\n',
#  ' Woh kon konse kaam hen ?\n',
#  ' Marketing assignment\n',
#  ' Finance assistant\n',
#  ' Assingment*\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' yeh jo network banana he\n',
#  ' Han\n',
#  ' sir ne kaha tha na keh yeh ap gender ki base pe diferentiate krwa do ya location ki base pe etc etc\n',
#  ' bas kisi ek ki base pe krna tha na\n',
#  ' mene gender ki base pe banaya he\n',
#  ' <Media omitted>\n',
#  ' <Media omitted>\n',
#  ' to yani yeh picture hamne 2 2 banani he ek baar workk liye ek baar departent k liye ?\n',
#  ' total 4 pictures ?\n',
#  ' Very nice\n',
#  'departments bhi krna h\n',
#  ' Mje iska interface tk nhi pta\n',
#  ' 1 sath hi 2 options choose nhi ho skte?\n',
#  ' Gender or department\n',
#  ' ni mujhe aisi koi option ni nazar ai\n',
#  ' Sir se pooch lein?\n',
#  ' chalen yeh kal sir se confirm kr lenge\n',
#  ' Haan theek ha\n',
#  ' a values wagera nikaal lete he done?\n',
#  ' aj*\n',
#  ' Yes🙌\n',
#  ' Company name kiya rkhna h\n',
#  ' Apni company ka\n',
#  ' schuitema😂\n',
#  ' Kumu🌚\n',
#  ' The Kumus\n',
#  ' yeh ap sochenphi\n',
#  ' Kumu means coach, teacher\n',
#  ' phir\n',
#  ' ',
#  ' wah bari research ki he\n',
#  ' g ap bhi kuch kren na ',
#  ...]

# %%
b = []
for i in a:
    if "\n" in a:
        b.append(i.split("\n")[0])
    else:
        b.append(i)

# %%
WAChat = b
WAChat[-1]
# Out:
# ' Peeche dekho'

# %%
f = open("data1.json", "r")
insta1 = json.loads(f.read())

# %%
messages = insta1["messages"]
# message = messages["content"]
# messages
insta1["messages"][7]["content"]
# Out:
# 'Me laga soney'

# %%
p = []
for i in messages:
    try:
        p.append(i["content"])
    except:
        pass

# %%
p
# Out:
# "Issue is he didn't attach images he used"

# %%
f2 = open("data2.json", "r")
insta2 = json.loads(f2.read())
messages2 = insta2["messages"]

# %%
# p = []
for i in messages2:
    try:
        p.append(i["content"])
#         print(i["content"])
    except:
        pass

# %%
len(p)
# Out:
# 12577

# %%
for i in p:
    b.append(i)

# %%
len(b)
# Out:
# 25396

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_19483/3161667991.py in <module>
# ----> 1 from chatterbot import ChatBot
#       2 from chatterbot.trainers import ListTrainer
#
# ModuleNotFoundError: No module named 'chatterbot'

# %%
# !pip install chatterbot
# Out:
# Collecting chatterbot
#   Downloading ChatterBot-1.0.5-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 901.7 kB/s eta 0:00:00MB/s eta 0:00:01
# Collecting pint>=0.8.1
#   Downloading Pint-0.20.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.5/269.5 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting python-dateutil<2.8,>=2.7
#   Downloading python_dateutil-2.7.5-py2.py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting mathparse<0.2,>=0.1
#   Downloading mathparse-0.1.2-py3-none-any.whl (7.2 kB)
# Collecting sqlalchemy<1.3,>=1.2
#   Downloading SQLAlchemy-1.2.19.tar.gz (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 678.8 kB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk<4.0,>=3.2 in /home/shahrukh/anaconda3/lib/python3.8/site-packages (from chatterbot) (3.7)
# Collecting pymongo<4.0,>=3.3
#   Downloading pymongo-3.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.2/526.2 kB 343.8 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: pytz in /home/shahrukh/.local/lib/python3.8/site-packages (from chatterbot) (2019.1)
# Collecting spacy<2.2,>=2.1
#   Downloading spacy-2.1.9.tar.gz (30.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 354.7 kB/s eta 0:00:00m eta 0:00:010:00:03
#   Installing build dependencies ... /
