# %%
from github import Github

# %%
Access_Token = open('/home/shahrukh/Desktop/GPT/token.txt', 'r').read()
g = Github(Access_Token)
print(g.get_user())
# Out:
# AuthenticatedUser(login=None)

# %%
query = 'flask language:python created:{start_time}..{end_time}'
result = g.search_repositories(query)

# %%
result[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13963/2994649360.py in <module>
# ----> 1 result[1]
#
# ~/anaconda3/lib/python3.8/site-packages/github/PaginatedList.py in __getitem__(self, index)
#      46         assert isinstance(index, (int, slice))
#      47         if isinstance(index, int):
# ---> 48             self.__fetchToIndex(index)
#      49             return self.__elements[index]
#      50         else:
#
# ~/anaconda3/lib/python3.8/site-packages/github/PaginatedList.py in __fetchToIndex(self, index)
#      62     def __fetchToIndex(self, index):
#      63         while len(self.__elements) <= index and self._couldGrow():
# ---> 64             self._grow()
#      65
#      66     def _grow(self):
#
# ~/anaconda3/lib/python3.8/site-packages/github/PaginatedList.py in _grow(self)
#      65
#      66     def _grow(self):
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13963/3943156338.py in <module>
# ----> 1 result.totalCount
#
# ~/anaconda3/lib/python3.8/site-packages/github/PaginatedList.py in totalCount(self)
#     147             # set per_page = 1 so the totalCount is just the number of pages
#     148             params.update({"per_page": 1})
# --> 149             headers, data = self.__requester.requestJsonAndCheck(
#     150                 "GET", self.__firstUrl, parameters=params, headers=self.__headers
#     151             )
#
# ~/anaconda3/lib/python3.8/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     352     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#     353         return self.__check(
# --> 354             *self.requestJson(
# ...

# %%
import time
from datetime import datetime

end_time = time.time()
start_time = end_time - 86400

for i in range(5):
    start_time_str = datetime.utcfromtimestamp(start_time).strftime('%Y-%m-%d')
    end_time_str = datetime.utcfromtimestamp(end_time).strftime('%Y-%m-%d')
    
    query = f"flask language:python created:{start_time}..{end_time}"
    print(query)
    
    start_time -= 86400
    end_time -= 86400
# Out:
# flask language:python created:1672080644.5636568..1672167044.5636568
# flask language:python created:1671994244.5636568..1672080644.5636568
# flask language:python created:1671907844.5636568..1671994244.5636568
# flask language:python created:1671821444.5636568..1671907844.5636568
# flask language:python created:1671735044.5636568..1671821444.5636568
